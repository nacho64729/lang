# %%
import random

# %%
a_EN = ["a", "ka", "sa", "ta", "na", "ha", "ma", "ya", "ra", "wa", "ga", "za", "da", "ba", "pa"]
a_JA = "あかさたなはまやらわがざだばぱ"

# %%
random.choice(a_EN)
# Out:
# 'ta'

# %%
random.choice(a_JA)
# Out:
# 'ら'

# %%
print(random.sample(a_EN, len(a_EN)))
# Out:
# ['na', 'pa', 'sa', 'a', 'ga', 'da', 'ba', 'ra', 'ma', 'za', 'ka', 'ha', 'ta', 'wa', 'ya']

# %%
chars = list(a_JA)
random.shuffle(chars)
shuffled = ''.join(chars)
shuffled
# Out:
# 'まさらやあがなはわだぱかたばざ'
